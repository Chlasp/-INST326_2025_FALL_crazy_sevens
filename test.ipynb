# %%
def computer_turn(computer_player, last_value, round):
    """_summary_

    Args:
        computer_player (_type_): _description_
        last_value (_type_): _description_
        round (_type_): _description_

    Returns:
        _type_: _description_
    """
    # Dummy Values
    computer_player.hand = [7,8,8,8,9,10]
    playable_hand = [card for card in sorted(computer_player.hand) \
        if card > last_value]
    count = {}
    for card in playable_hand:
        count[card] = count.get(card, 0) + 1
    double_hand = [card for card in playable_hand if count[card] > 1]
    if round == 3:
        if double_hand:
            chosen = double_hand[0]
            computer_player.hand = [x for x in playable_hand if x != chosen]
            return [x for x in playable_hand if x == chosen]
        chosen = playable_hand[0]
        computer_player.hand = [x for x in playable_hand if x != chosen]
        return [x for x in playable_hand if x == chosen]
    else:
        if (playable_hand[0] - 3)  
class Computer():
    def __init__(self):
        pass
c = Computer()
computer = computer_turn(c,6,3)
print(computer)
# Out:
# [8, 8, 8]
